# %% [markdown]
# # Generate mesh in `gmsh`

# %%
import gmsh

# %%
l_1 = 50  # side length of small cube
l_2 = 250  # side length of big cube

# %%
# Initialize model
gmsh.initialize()
model = gmsh.model()

model.add("Omega")

# %%
small_cube = model.occ.add_box(0, 0, 0, l_1, l_1, l_1)
model.occ.translate([(3, small_cube)], -l_1/2, -l_1/2, -l_1/2)
big_cube = model.occ.add_box(0, 0, 0, l_2, l_2, l_2)
model.occ.translate([(3, big_cube)], -l_2/2, -l_2/2, -l_2/2)
out_dim, _ = model.occ.cut(
    [(3, big_cube)],
    [(3, small_cube)],
    removeObject=False,
    removeTool=False
)  # out_dim is a list of tuples (dim, tag). In this case it will be [(3, 3)]
shell = out_dim[0][1]  # tag of the shell
model.occ.synchronize()

# %%
boundaries = model.get_boundary([(3, big_cube)])  # This extracts the boundary from the entity `big_cube` (that has dimension 3)
boundary_surface = boundaries[0][1]  # `boundary` is a list of tuples (dim, tag). In this case it will be [(2, 1)]
model.remove_entities([(3, big_cube)])  # We remove the bigger cube as we do not need it

# %% [markdown]
# Define tags:

# %%
model.add_physical_group(3, [small_cube], name="core")
model.add_physical_group(3, [shell], name="shell")
model.add_physical_group(2, [boundary_surface], name="boundary")
# Out:
# 3

# %% [markdown]
# Specify mesh options and generate the mesh.

# %%
model.mesh.set_size(model.get_entities(0), 10)  # assign mesh size 10 to all points
model.mesh.set_size(model.get_entities(2), 10)
eps=1e-3
points_in_core = model.get_entities_in_bounding_box(-25-eps, -25-eps, -25-eps, 25+eps, 25+eps, 25+eps)
model.mesh.set_size(points_in_core, 2)

# %%
model.mesh.generate(3)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 20%] Meshing curve 4 (Line)
# Info    : [ 20%] Meshing curve 5 (Line)
# Info    : [ 30%] Meshing curve 6 (Line)
# Info    : [ 30%] Meshing curve 7 (Line)
# Info    : [ 30%] Meshing curve 8 (Line)
# Info    : [ 40%] Meshing curve 9 (Line)
# Info    : [ 40%] Meshing curve 10 (Line)
# Info    : [ 50%] Meshing curve 11 (Line)
# Info    : [ 50%] Meshing curve 12 (Line)
# Info    : [ 60%] Meshing curve 13 (Line)
# Info    : [ 60%] Meshing curve 14 (Line)
# Info    : [ 60%] Meshing curve 15 (Line)
# Info    : [ 70%] Meshing curve 16 (Line)
# Info    : [ 70%] Meshing curve 17 (Line)
# Info    : [ 80%] Meshing curve 18 (Line)
# Info    : [ 80%] Meshing curve 19 (Line)
# Info    : [ 80%] Meshing curve 20 (Line)
# Info    : [ 90%] Meshing curve 21 (Line)
# Info    : [ 90%] Meshing curve 22 (Line)
# Info    : [100%] Meshing curve 23 (Line)
# Info    : [100%] Meshing curve 24 (Line)
# Info    : Done meshing 1D (Wall 0.0041392s, CPU 0.001602s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 7 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 8 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 9 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 10 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 11 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 12 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.249679s, CPU 0.242202s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 2 volumes with 1 connected component
# Info    : Tetrahedrizing 8855 nodes...
# Info    : Done tetrahedrizing 8863 nodes (Wall 0.164272s, CPU 0.161259s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.292176s, CPU 0.271208s)
# Info    : Found volume 3
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 12.7798 (nodes removed 0 0)
# Info    : It. 500 - 500 nodes created - worst tet radius 4.30259 (nodes removed 0 0)
# Info    : It. 1000 - 1000 nodes created - worst tet radius 3.32789 (nodes removed 0 0)
# Info    : It. 1500 - 1500 nodes created - worst tet radius 2.98664 (nodes removed 0 0)
# Info    : It. 2000 - 2000 nodes created - worst tet radius 2.65865 (nodes removed 0 0)
# Info    : It. 2500 - 2500 nodes created - worst tet radius 2.46729 (nodes removed 0 0)
# Info    : It. 3000 - 3000 nodes created - worst tet radius 2.32633 (nodes removed 0 0)
# Info    : It. 3500 - 3500 nodes created - worst tet radius 2.2049 (nodes removed 0 0)
# Info    : It. 4000 - 4000 nodes created - worst tet radius 2.10733 (nodes removed 0 0)
# Info    : It. 4500 - 4500 nodes created - worst tet radius 2.02931 (nodes removed 0 0)
# Info    : It. 5000 - 5000 nodes created - worst tet radius 1.96177 (nodes removed 0 0)
# Info    : It. 5500 - 5500 nodes created - worst tet radius 1.90458 (nodes removed 0 0)
# Info    : It. 6000 - 6000 nodes created - worst tet radius 1.85302 (nodes removed 0 0)
# Info    : It. 6500 - 6500 nodes created - worst tet radius 1.80231 (nodes removed 0 0)
# Info    : It. 7000 - 7000 nodes created - worst tet radius 1.76113 (nodes removed 0 0)
# Info    : It. 7500 - 7500 nodes created - worst tet radius 1.72261 (nodes removed 0 0)
# Info    : It. 8000 - 8000 nodes created - worst tet radius 1.68664 (nodes removed 0 0)
# Info    : It. 8500 - 8500 nodes created - worst tet radius 1.65274 (nodes removed 0 0)
# Info    : It. 9000 - 9000 nodes created - worst tet radius 1.6234 (nodes removed 0 0)
# Info    : It. 9500 - 9500 nodes created - worst tet radius 1.59401 (nodes removed 0 0)
# Info    : It. 10000 - 10000 nodes created - worst tet radius 1.56816 (nodes removed 0 0)
# Info    : It. 10500 - 10500 nodes created - worst tet radius 1.54194 (nodes removed 0 0)
# Info    : It. 11000 - 11000 nodes created - worst tet radius 1.51978 (nodes removed 0 0)
# Info    : It. 11500 - 11500 nodes created - worst tet radius 1.49881 (nodes removed 0 0)
# Info    : It. 12000 - 12000 nodes created - worst tet radius 1.47791 (nodes removed 0 0)
# Info    : It. 12500 - 12500 nodes created - worst tet radius 1.45926 (nodes removed 0 0)
# Info    : It. 13000 - 13000 nodes created - worst tet radius 1.43923 (nodes removed 0 0)
# Info    : It. 13500 - 13500 nodes created - worst tet radius 1.42007 (nodes removed 0 0)
# Info    : It. 14000 - 14000 nodes created - worst tet radius 1.40293 (nodes removed 0 0)
# Info    : It. 14500 - 14500 nodes created - worst tet radius 1.38614 (nodes removed 0 0)
# Info    : It. 31000 - 31000 nodes created - worst tet radius 1.08613 (nodes removed 0 0)
# Info    : It. 31500 - 31500 nodes created - worst tet radius 1.08076 (nodes removed 0 0)
# Info    : It. 32000 - 32000 nodes created - worst tet radius 1.07546 (nodes removed 0 0)
# Info    : It. 32500 - 32500 nodes created - worst tet radius 1.06993 (nodes removed 0 0)
# Info    : It. 33000 - 33000 nodes created - worst tet radius 1.06435 (nodes removed 0 0)
# Info    : It. 33500 - 33500 nodes created - worst tet radius 1.05928 (nodes removed 0 0)
# Info    : It. 34000 - 34000 nodes created - worst tet radius 1.05449 (nodes removed 0 0)
# Info    : It. 34500 - 34500 nodes created - worst tet radius 1.04936 (nodes removed 0 0)
# Info    : It. 35000 - 35000 nodes created - worst tet radius 1.04452 (nodes removed 0 0)
# Info    : It. 35500 - 35500 nodes created - worst tet radius 1.03981 (nodes removed 0 0)
# Info    : It. 36000 - 36000 nodes created - worst tet radius 1.03495 (nodes removed 0 0)
# Info    : It. 36500 - 36500 nodes created - worst tet radius 1.03059 (nodes removed 0 0)
# Info    : It. 37000 - 37000 nodes created - worst tet radius 1.02611 (nodes removed 0 0)
# Info    : It. 37500 - 37500 nodes created - worst tet radius 1.02175 (nodes removed 0 0)
# Info    : It. 38000 - 38000 nodes created - worst tet radius 1.01739 (nodes removed 0 0)
# Info    : It. 38500 - 38500 nodes created - worst tet radius 1.01295 (nodes removed 0 0)
# Info    : It. 39000 - 39000 nodes created - worst tet radius 1.00859 (nodes removed 0 0)
# Info    : It. 39500 - 39500 nodes created - worst tet radius 1.00472 (nodes removed 0 0)
# Info    : It. 40000 - 40000 nodes created - worst tet radius 1.00063 (nodes removed 0 0)
# Info    : 3D refinement terminated (48927 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 296688 tetrahedra created in 2.7413 sec. (108228 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 4.73316s, CPU 4.68313s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 125000) with worst = 0.00710062 / average = 0.785127:
# Info    : 0.00 < quality < 0.10 :       152 elements
# Info    : 0.10 < quality < 0.20 :       460 elements
# Info    : 0.20 < quality < 0.30 :       761 elements
# Info    : 0.30 < quality < 0.40 :      1185 elements
# Info    : 0.40 < quality < 0.50 :      1901 elements
# Info    : 0.50 < quality < 0.60 :      2998 elements
# Info    : 0.60 < quality < 0.70 :      6886 elements
# Info    : 0.70 < quality < 0.80 :     16282 elements
# Info    : 0.80 < quality < 0.90 :     27514 elements
# Info    : 0.90 < quality < 1.00 :     14448 elements
# Info    : 1362 edge swaps, 32 node relocations (volume = 125000): worst = 0.121025 / average = 0.796979 (Wall 0.0380931s, CPU 0.03816s)
# Info    : 1368 edge swaps, 32 node relocations (volume = 125000): worst = 0.300017 / average = 0.797033 (Wall 0.0491497s, CPU 0.04929s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :      1192 elements
# Info    : 0.40 < quality < 0.50 :      1817 elements
# Info    : 0.50 < quality < 0.60 :      2867 elements
# Info    : 0.60 < quality < 0.70 :      6911 elements
# Info    : 0.70 < quality < 0.80 :     16468 elements
# Info    : 0.80 < quality < 0.90 :     27737 elements
# Info    : 0.90 < quality < 1.00 :     14377 elements
# Info    : Optimizing volume 3
# Info    : Optimization starts (volume = 1.55e+07) with worst = 0.00715234 / average = 0.780402:
# Info    : 0.00 < quality < 0.10 :       437 elements
# Info    : 0.10 < quality < 0.20 :      1396 elements
# Info    : 0.20 < quality < 0.30 :      2383 elements
# Info    : 0.30 < quality < 0.40 :      3903 elements
# Info    : 0.40 < quality < 0.50 :      6192 elements
# Info    : 0.50 < quality < 0.60 :     10802 elements
# Info    : 0.60 < quality < 0.70 :     21687 elements
# Info    : 0.70 < quality < 0.80 :     50744 elements
# Info    : 0.80 < quality < 0.90 :     83848 elements
# Info    : 0.90 < quality < 1.00 :     42702 elements
# Info    : 4166 edge swaps, 118 node relocations (volume = 1.55e+07): worst = 0.137756 / average = 0.792041 (Wall 0.11986s, CPU 0.120081s)
# Info    : 4191 edge swaps, 119 node relocations (volume = 1.55e+07): worst = 0.263712 / average = 0.792109 (Wall 0.157128s, CPU 0.157428s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :      3893 elements
# Info    : 0.40 < quality < 0.50 :      6004 elements
# Info    : 0.50 < quality < 0.60 :     10486 elements
# Info    : 0.60 < quality < 0.70 :     21514 elements
# Info    : 0.70 < quality < 0.80 :     51423 elements
# Info    : 0.80 < quality < 0.90 :     84569 elements
# Info    : 0.90 < quality < 1.00 :     42447 elements
# Info    : Done optimizing mesh (Wall 0.720197s, CPU 0.698611s)
# Info    : 48927 nodes 310031 elements

# %% [markdown]
# Run GUI:

# %%
gmsh.fltk.run()
# Out:
# XOpenIM() failed
# X_ChangeProperty: BadValue (integer parameter out of range for operation) 0x0
# -------------------------------------------------------
# Version       : 4.13.1
# License       : GNU General Public License
# Build OS      : Linux64-sdk
# Build date    : 20241016
# Build host    : 2976249cf102
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blossom Cairo DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack LinuxJoystick MathEx[contrib] Mesh Metis[contrib] Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] Untangle Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.3.9
# OCC version   : 7.8.1
# Packaged by   : conda
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------

# %% [markdown]
# Write mesh to file:

# %%
gmsh.write("./Omega.msh")
gmsh.finalize()
# Out:
# Info    : Writing './Omega.msh'...
# Info    : Done writing './Omega.msh'
